# %% [markdown]
# # End of game measures
# This `Python` notebook takes the anonymized data and computes population-level measures for each game.

# %%
# %pylab inline
import json
import numpy as np
import pandas as pd
import glob
import itertools
from sklearn.decomposition import PCA
from scipy import stats

from helpers import shuffle
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
output_dir = "../results-anonymized/experiment/"
files = glob.glob(output_dir+'block_*.json')
sorted(files)
# Out:
# ['../results-anonymized/experiment/block_0.json',
#  '../results-anonymized/experiment/block_1.json',
#  '../results-anonymized/experiment/block_10.json',
#  '../results-anonymized/experiment/block_11.json',
#  '../results-anonymized/experiment/block_12.json',
#  '../results-anonymized/experiment/block_13.json',
#  '../results-anonymized/experiment/block_14.json',
#  '../results-anonymized/experiment/block_15.json',
#  '../results-anonymized/experiment/block_16.json',
#  '../results-anonymized/experiment/block_17.json',
#  '../results-anonymized/experiment/block_18.json',
#  '../results-anonymized/experiment/block_19.json',
#  '../results-anonymized/experiment/block_2.json',
#  '../results-anonymized/experiment/block_20.json',
#  '../results-anonymized/experiment/block_21.json',
#  '../results-anonymized/experiment/block_22.json',
#  '../results-anonymized/experiment/block_23.json',
#  '../results-anonymized/experiment/block_24.json',
#  '../results-anonymized/experiment/block_25.json',
#  '../results-anonymized/experiment/block_26.json',
#  '../results-anonymized/experiment/block_27.json',
#  '../results-anonymized/experiment/block_28.json',
#  '../results-anonymized/experiment/block_29.json',
#  '../results-anonymized/experiment/block_3.json',
#  '../results-anonymized/experiment/block_4.json',
#  '../results-anonymized/experiment/block_5.json',
#  '../results-anonymized/experiment/block_6.json',
#  '../results-anonymized/experiment/block_7.json',
#  '../results-anonymized/experiment/block_8.json',
#  '../results-anonymized/experiment/block_9.json']

# %%
len(files)
# Out:
# 30

# %%
blocks = []
for file in files:
    with open(file) as f:
        blocks.append(json.load(f))

# %%
# Enumerate clues to be used in polarization analysis
# final clues used in analysis are connections between hub nodes (1,2) and rim nodes (3-13)
t_spokes = ['tclue_1_3', 'tclue_1_4', 'tclue_1_5', 'tclue_1_6', 'tclue_1_7', 
            'tclue_1_8', 'tclue_1_9', 'tclue_1_10','tclue_1_11', 'tclue_1_12', 'tclue_1_13',
            'tclue_2_3', 'tclue_2_4', 'tclue_2_5', 'tclue_2_6', 'tclue_2_7',
            'tclue_2_8', 'tclue_2_9', 'tclue_2_10', 'tclue_2_11', 'tclue_2_12', 'tclue_2_13']

c_spokes = ['cclue_1_3', 'cclue_1_4', 'cclue_1_5', 'cclue_1_6', 'cclue_1_7', 
            'cclue_1_8', 'cclue_1_9', 'cclue_1_10','cclue_1_11', 'cclue_1_12', 'cclue_1_13',
            'cclue_2_3', 'cclue_2_4', 'cclue_2_5', 'cclue_2_6', 'cclue_2_7',
            'cclue_2_8', 'cclue_2_9', 'cclue_2_10', 'cclue_2_11', 'cclue_2_12', 'cclue_2_13']

# Enumerate end-of-game survey questions to be used in polarization analysis
assessments = ['appearance_1', 'appearance_2', 
               'clothing_1', 'clothing_2',
               'suspect_1', 'suspect_2', 'suspect_3',
               'tool_1', 'tool_2', 
               'vehicle_1', 'vehicle_2']    
    
def compute_single_point_measures(game, n_used):
    """ 
    Compute the game-level measures 
    
    "Games" in this experiment contain both a treatment and control condition
    and these must be properly separated from one another.
    
    """
    # Form end-of-game survey responses into a dataframe
    collector = {}
    for p, k in game['players'].items():
        try:
            collector[k['data.position']] = k['data.caseMade']
        except:
            print('%s did not complete the post-game survey' %k['data.position'])
    responses = pd.DataFrame(collector).T.sort_index()

    # Form final notebook states into a dataframe
    final_adoptions = pd.DataFrame(data=0, index=responses.index, columns=t_spokes+c_spokes)
    for p, k in game['players'].items():
        for clue_id in k['data.notebooks']['promising_leads']['clueIDs']:
            final_adoptions.loc[k['data.position'], clue_id] = 1


    # Determine the number of datapoints to be used in polarization analysis
    # if there are missing responses, need to compare equal sized datasets
    t_responses = [pos for pos in responses.index if pos.startswith('t')]
    c_responses = [pos for pos in responses.index if pos.startswith('c')] 
    # use whichever condition has fewer responses to set the sample size
    #n_used = min(len(t_responses), len(c_responses))


    def process_subset(subset, spokes):
        """ compute a result on the selected subset of the data """
        sub_res = {}
        
        # select the subset of the survey responses that will be used in the subset analysis
        sub_survey = responses.loc[subset, assessments]
        
        # survey PC1 
        pca = PCA(n_components=1)
        pca.fit(sub_survey)  
        sub_res['survey PC1'] = pca.explained_variance_ratio_

        # survey similarity percentiles
        survey_corrs = sub_survey.T.corr().mask(np.tri(n_used, n_used, 0, dtype='bool')).stack()
        sub_res['survey 5% similarity'], sub_res['survey 95% similarity'] = np.percentile(
            survey_corrs, [5, 95])
        
        # select the subset of the behavioral responses that will be used in the subset analysis
        sub_adopt = final_adoptions.loc[subset, spokes]
        
        # final-state PC1
        pca = PCA(n_components=1)
        pca.fit(sub_adopt)  
        sub_res['spoke PC1'] = pca.explained_variance_ratio_
        
        # final state similarity percentiles
        spoke_corrs = sub_adopt.T.corr().mask(np.tri(n_used, n_used, 0, dtype='bool')).stack()
        sub_res['spoke 5% similarity'], sub_res['spoke 95% similarity'] = np.percentile(
            spoke_corrs, [5, 95])
        
        # compute the expected values for the given level of adoption
        # by shuffling the clues between individuals 
        # (preserving the number of clues each individual holds, 
        # and the number of individuals holding each clue)
        # do this a number of times and average the result
        e95 = []
        e5 = []
        ePC1 = []
        for _ in range(100):
            shuffle_adopt = pd.DataFrame(index=sub_adopt.index,
                                         columns=sub_adopt.columns,
                                         data=shuffle(sub_adopt.values, n=500))

            n_agents = len(shuffle_adopt.index)
            corrs = shuffle_adopt.astype(float).T.corr().mask(np.tri(n_agents, n_agents, 0, dtype='bool')).stack()
            e95.append(np.percentile(corrs, 95))
            e5.append(np.percentile(corrs, 5))

            pca = PCA(n_components=1)
            pca.fit(shuffle_adopt)
            ePC1.append(pca.explained_variance_ratio_[0])
        
        # compute the net effect of (interdependent or independent) diffusion 
        # over chance distribution of the same clues
        sub_res['net spoke PC1'] = sub_res['spoke PC1'] - np.mean(ePC1)
        sub_res['net spoke 95% similarity'] = sub_res['spoke 95% similarity'] - np.mean(e95)
        sub_res['net spoke 5% similarity'] = sub_res['spoke 5% similarity'] - np.mean(e5)
        
        return sub_res
        
        
    # For each subset of size 'n_used', compute a result. 
    # In most cases there are no missing responses, so just compute on the complete set
    t_collector = []
    for subset in itertools.combinations(t_responses, r=n_used):
        t_collector.append(process_subset(subset, t_spokes))

    # The recorded result is the average over all subsets
    if len(t_collector) > 1:
        print('Averaging over %i combinations for treatment case'%len(t_collector))
    t_result = pd.DataFrame(t_collector).mean()

    # Compute average for confidence and consensus measures on all submissions
    t_result['confidence'] = responses.loc[t_responses, 'confidence'].mean()
    t_result['consensus'] = responses.loc[t_responses, 'consensus'].mean()    
    t_result['id'] = game['_id']
    
    # Perform the same analysis as above for the control condition
    c_collector = []
    for subset in itertools.combinations(c_responses, r=n_used):
        c_collector.append(process_subset(subset, c_spokes))

    if len(c_collector) > 1:
        print('Averaging over %i combinations for control case'%len(c_collector))
    c_result = pd.DataFrame(c_collector).mean()

    c_result['confidence'] = responses.loc[c_responses, 'confidence'].mean()
    c_result['consensus'] = responses.loc[c_responses, 'consensus'].mean()     

    c_result['id'] = game['_id']
    
    #pd.merge(t_result, c)result, suffixes=(' (inter)', ' (indep)'))
    result = pd.concat([t_result, c_result], keys=['inter', 'indep'])
    #result['game_id']=game['createdAt'].split('_')[0].replace('-','_').replace(':','_').replace('.','_')
    return result

def compute_block(block):
    results_collector = []
    network_collector = []
    
    # identify the number of players to use in averages to account for dropouts.
    min_players = 20
    for name, game in block.items():
        c_count = 0
        t_count = 0
        for p, k in game['players'].items():
            if 'data.caseMade' in k:
                if k["data.position"][0] == "t":
                    t_count += 1
                elif k["data.position"][0] == "c":
                    c_count += 1
        min_players = min(min_players, t_count, c_count)
    
    for name, game in block.items():
        network_collector.append('caveman' if 'caveman' in name else 'dodec')
        results_collector.append(compute_single_point_measures(game, n_used=min_players))
        
    result = pd.concat(results_collector, keys=network_collector)
    return result

# %%
import multiprocessing

with multiprocessing.Pool(3) as p:
    measurements_list = p.map(compute_block, blocks)
measurements = pd.concat(measurements_list, axis=1)
#measurements.to_csv(output_dir+"end_of_game_measurements.csv")
measurements
# Out:
# c12 did not complete the post-game survey
# c17 did not complete the post-game survey
# c19 did not complete the post-game survey
# Averaging over 20 combinations for treatment case
# Averaging over 20 combinations for treatment case
# c13 did not complete the post-game survey
# t12 did not complete the post-game survey
# c4 did not complete the post-game survey
# Averaging over 20 combinations for treatment case
# t10 did not complete the post-game survey
# Averaging over 20 combinations for treatment case
# t5 did not complete the post-game survey
# c6 did not complete the post-game survey
# c17 did not complete the post-game survey
# Averaging over 20 combinations for control case
# Averaging over 20 combinations for treatment case
# t10 did not complete the post-game survey
# t19 did not complete the post-game survey
# Averaging over 190 combinations for treatment case
# Averaging over 190 combinations for treatment case
# Averaging over 190 combinations for control case
# t5 did not complete the post-game survey
# t16 did not complete the post-game survey
# Averaging over 190 combinations for control case
# t10 did not complete the post-game survey
# t12 did not complete the post-game survey
# Averaging over 190 combinations for control case
# t9 did not complete the post-game survey
# c7 did not complete the post-game survey
# c3 did not complete the post-game survey
# Averaging over 190 combinations for control case
# c13 did not complete the post-game survey
# t8 did not complete the post-game survey
# Averaging over 19 combinations for treatment case
# t15 did not complete the post-game survey
# Averaging over 20 combinations for treatment case
# Averaging over 19 combinations for treatment case
# Averaging over 20 combinations for control case
# c3 did not complete the post-game survey
# Averaging over 20 combinations for treatment case
# t0 did not complete the post-game survey
# Averaging over 20 combinations for control case
# t5 did not complete the post-game survey
# t12 did not complete the post-game survey
# Averaging over 190 combinations for control case
# Averaging over 190 combinations for control case
# t6 did not complete the post-game survey
# t4 did not complete the post-game survey
# Averaging over 190 combinations for control case
# t3 did not complete the post-game survey
# Averaging over 19 combinations for treatment case
# Averaging over 190 combinations for control case
# t3 did not complete the post-game survey
# c2 did not complete the post-game survey
# t14 did not complete the post-game survey
# Averaging over 20 combinations for control case
# Averaging over 20 combinations for treatment case
# Averaging over 190 combinations for control case
# t13 did not complete the post-game survey
# c18 did not complete the post-game survey
# c16 did not complete the post-game survey
# Averaging over 20 combinations for control case
# t9 did not complete the post-game survey
# c6 did not complete the post-game survey
# t6 did not complete the post-game survey
# Averaging over 20 combinations for treatment case
# c16 did not complete the post-game survey
# Averaging over 19 combinations for treatment case
# Averaging over 20 combinations for treatment case
# t16 did not complete the post-game survey
# c14 did not complete the post-game survey
# c18 did not complete the post-game survey
# t3 did not complete the post-game survey
# Averaging over 171 combinations for treatment case
# Averaging over 190 combinations for control case
# t8 did not complete the post-game survey
# c8 did not complete the post-game survey
# c19 did not complete the post-game survey
# Averaging over 19 combinations for treatment case
# t18 did not complete the post-game survey
# Averaging over 171 combinations for control case
# c7 did not complete the post-game survey
# c8 did not complete the post-game survey
# c6 did not complete the post-game survey
# Averaging over 171 combinations for treatment case
# Averaging over 1140 combinations for treatment case
# c0 did not complete the post-game survey
# Averaging over 20 combinations for treatment case
# Averaging over 20 combinations for treatment case
# Averaging over 20 combinations for control case
# c13 did not complete the post-game survey
# c16 did not complete the post-game survey
# t4 did not complete the post-game survey
# c8 did not complete the post-game survey
# Averaging over 1140 combinations for control case
# c15 did not complete the post-game survey
# c14 did not complete the post-game survey
# c18 did not complete the post-game survey
# Averaging over 171 combinations for treatment case
# t2 did not complete the post-game survey
# Averaging over 171 combinations for treatment case
# Averaging over 1140 combinations for treatment case
# t0 did not complete the post-game survey
# Averaging over 20 combinations for control case
# Averaging over 20 combinations for treatment case
# Averaging over 20 combinations for control case
# Averaging over 20 combinations for treatment case
# Averaging over 20 combinations for control case
# c6 did not complete the post-game survey
# Averaging over 20 combinations for treatment case
# c10 did not complete the post-game survey
# Averaging over 1140 combinations for control case
# c12 did not complete the post-game survey
# Averaging over 190 combinations for treatment case
# Averaging over 19 combinations for control case
# t17 did not complete the post-game survey
# t15 did not complete the post-game survey
# Averaging over 190 combinations for treatment case
# Averaging over 19 combinations for control case
# t17 did not complete the post-game survey
# t1 did not complete the post-game survey
# Averaging over 190 combinations for control case
# t2 did not complete the post-game survey
# c17 did not complete the post-game survey
# Averaging over 20 combinations for treatment case
# Averaging over 20 combinations for control case
# c0 did not complete the post-game survey
# c12 did not complete the post-game survey
# Averaging over 190 combinations for control case
# Averaging over 190 combinations for treatment case
# c3 did not complete the post-game survey
# Averaging over 190 combinations for treatment case
# Averaging over 19 combinations for control case
# Averaging over 4845 combinations for treatment case
# Averaging over 4845 combinations for control case
# t16 did not complete the post-game survey
# t3 did not complete the post-game survey
# t18 did not complete the post-game survey
# t8 did not complete the post-game survey
# Averaging over 4845 combinations for control case
#                                                        0                  1   \
# caveman indep confidence                          60.7368            58.9474
#               consensus                           58.2632            64.5789
#               id                        jcfFiGC22Api8cm7o  oWf8QrmFrj8ZiE6JK
#               net spoke 5% similarity           -0.109577         -0.0424096
#               net spoke 95% similarity           0.181881           0.399487
#               net spoke PC1                      0.168423           0.213552
#               spoke 5% similarity               -0.267283          -0.271448
#               spoke 95% similarity               0.770833           0.906105
#               spoke PC1                          0.356007           0.392184
#               survey 5% similarity              -0.480858          -0.465191
#               survey 95% similarity              0.577215            0.63842
#               survey PC1                         0.285638           0.435887
#         inter confidence                             54.8                 51
#               consensus                             53.35            54.7368
#               id                        jcfFiGC22Api8cm7o  oWf8QrmFrj8ZiE6JK
#               net spoke 5% similarity          -0.0511019          -0.102545
#               net spoke 95% similarity            0.18809           0.298607
#               net spoke PC1                      0.146933           0.266818
#               spoke 5% similarity               -0.243468          -0.297247
#               spoke 95% similarity               0.770392           0.856077
#               spoke PC1                          0.338543           0.477807
#               survey 5% similarity              -0.307725          -0.584629
#               survey 95% similarity              0.832922           0.620587
#               survey PC1                         0.330469           0.361485
# dodec   indep confidence                               53            59.5263
#               consensus                           48.7895            58.7368
#               id                        Lj2up2ePZA6WtiK4q  MfjKnfErfu8AMLKps
#               net spoke 5% similarity             -0.1451         -0.0384423
#               net spoke 95% similarity           0.100071          0.0528489
#               net spoke PC1                     0.0472661          0.0482177
#               spoke 5% similarity                -0.11606          -0.190387
#               spoke 95% similarity               0.748331           0.602642
#               spoke PC1                          0.276937           0.303827
#               survey 5% similarity              -0.415275          -0.544103
#               survey 95% similarity               0.78428           0.591943
#               survey PC1                         0.280021           0.271119
#         inter confidence                             55.1              59.95
#               consensus                             49.95              59.45
#               id                        Lj2up2ePZA6WtiK4q  MfjKnfErfu8AMLKps
#               net spoke 5% similarity           -0.088241         -0.0320646
#               net spoke 95% similarity           0.151271           0.078218
#               net spoke PC1                     0.0868931         0.00468548
#               spoke 5% similarity                -0.26717           -0.21278
#               spoke 95% similarity               0.677797           0.636078
#               spoke PC1                          0.286886           0.241828
#               survey 5% similarity              -0.487964          -0.543287
#               survey 95% similarity              0.620877           0.745163
#               survey PC1                         0.328971           0.425684
#
#                                                        2                  3   \
# caveman indep confidence                            62.35            49.5789
#               consensus                              59.9            55.2632
#               id                        mSJbtZFsaaWC3ANqy  b4CBPunda96KnrhFi
#               net spoke 5% similarity          -0.0894584         -0.0976456
#               net spoke 95% similarity           0.363955           0.206318
#               net spoke PC1                      0.186457            0.15565
#               spoke 5% similarity               -0.291655          -0.110657
#               spoke 95% similarity               0.881366           0.845124
#               spoke PC1                          0.375846           0.348715
#               survey 5% similarity              -0.448069          -0.301127
#               survey 95% similarity              0.738817           0.718672
#               survey PC1                         0.397625           0.384445
#         inter confidence                          57.8333            66.6316
#               consensus                           55.6111            62.6842
#               id                        mSJbtZFsaaWC3ANqy  b4CBPunda96KnrhFi
#               net spoke 5% similarity          -0.0725466          -0.189721
#               net spoke 95% similarity           0.287296           0.140614
#               net spoke PC1                      0.178193           0.248583
#               spoke 5% similarity               -0.314369          -0.152535
#               spoke 95% similarity                 0.7698            0.82102
#               spoke PC1                          0.372501           0.453123
#               survey 5% similarity              -0.566077          -0.180965
#               survey 95% similarity              0.641932           0.911979
#               survey PC1                         0.288259           0.476976
# dodec   indep confidence                             70.9            51.3684
#               consensus                             65.85            54.6842
#               id                        rtzgQPuxzH7dGbna4  EFdcytJKJJAgFebvR
#               net spoke 5% similarity          -0.0643568         -0.0543929
#               net spoke 95% similarity           0.148598         -0.0257837
#               net spoke PC1                      0.127138          0.0366319
#               spoke 5% similarity               -0.143474          0.0578654
#               spoke 95% similarity               0.745892           0.691978
#               spoke PC1                          0.388072           0.245484
#               survey 5% similarity               -0.40554          -0.225784
#               survey 95% similarity              0.710164            0.81374
#               survey PC1                          0.38411           0.403655
#         inter confidence                          65.4444               45.7
#               consensus                           55.8889              39.05
#               id                        rtzgQPuxzH7dGbna4  EFdcytJKJJAgFebvR
#               net spoke 5% similarity          -0.0392158         -0.0207989
#               net spoke 95% similarity           0.130515           0.030951
#               net spoke PC1                     0.0704261          0.0318124
#               spoke 5% similarity               -0.257521          -0.166637
#               spoke 95% similarity               0.651795            0.63266
#               spoke PC1                          0.273769           0.226773
#               survey 5% similarity              -0.383497          -0.481496
#               survey 95% similarity              0.707254           0.645977
#               survey PC1                         0.336347           0.275144
#
#                                                        4                  5   \
# caveman indep confidence                            52.25               57.5
#               consensus                             52.65               54.4
#               id                        NkvLcmxvQY36f759u  qQyhQa275SKLzM3X9
#               net spoke 5% similarity          -0.0852608         -0.0842348
#               net spoke 95% similarity           0.230887           0.211961
#               net spoke PC1                      0.151902           0.203184
#               spoke 5% similarity               -0.321101          -0.253218
#               spoke 95% similarity               0.705407           0.780618
#               spoke PC1                          0.345412           0.410325
#               survey 5% similarity              -0.482257          -0.471916
#               survey 95% similarity              0.671286           0.638336
#               survey PC1                         0.369329           0.306379
#         inter confidence                            58.35              57.75
#               consensus                              63.4              53.25
#               id                        NkvLcmxvQY36f759u  qQyhQa275SKLzM3X9
#               net spoke 5% similarity          -0.0317437          -0.115293
#               net spoke 95% similarity           0.248322           0.305303
#               net spoke PC1                      0.106253           0.265748
#               spoke 5% similarity               -0.250622          -0.366721
#               spoke 95% similarity               0.713003           0.794973
#               spoke PC1                          0.297114           0.470965
#               survey 5% similarity              -0.589132          -0.470796
#               survey 95% similarity              0.622937           0.762261
#               survey PC1                         0.383931           0.454784
# dodec   indep confidence                             55.7               63.4
#               consensus                             56.65               60.9
#               id                        yAmdFLN5XZJ6SxeKL  c2BKscFKSBaujzQHw
#               net spoke 5% similarity           -0.114622         -0.0540356
#               net spoke 95% similarity          0.0699193          0.0317887
#               net spoke PC1                     0.0551171        -0.00226073
#               spoke 5% similarity               -0.200985         -0.0714468
#               spoke 95% similarity               0.671893           0.665081
#               spoke PC1                          0.271352           0.326751
#               survey 5% similarity               -0.48131          -0.479056
#               survey 95% similarity              0.647406           0.561405
#               survey PC1                         0.267282           0.299868
#         inter confidence                          63.1111            60.6875
#               consensus                           57.0556              58.75
#               id                        yAmdFLN5XZJ6SxeKL  c2BKscFKSBaujzQHw
#               net spoke 5% similarity          -0.0652012         -0.0436252
#               net spoke 95% similarity           0.224355            0.15789
#               net spoke PC1                      0.100033          0.0829486
#               spoke 5% similarity                -0.23689          -0.245483
#               spoke 95% similarity               0.790476           0.647382
#               spoke PC1                          0.300444           0.328404
#               survey 5% similarity              -0.562809          -0.331286
#               survey 95% similarity              0.628879            0.68029
#               survey PC1                         0.314442           0.250513
#
#                                                        6                  7   \
# caveman indep confidence                             55.5            56.3889
#               consensus                              53.2            51.1667
#               id                        9oijjTA5XEFzCtedK  2RErnuyZ5YmzTzpxh
#               net spoke 5% similarity          -0.0395781          -0.152822
#               net spoke 95% similarity           0.205684           0.349527
#               net spoke PC1                      0.138845           0.227126
#               spoke 5% similarity               -0.105496           -0.37918
#               spoke 95% similarity               0.807523           0.815588
#               spoke PC1                           0.32753           0.428915
#               survey 5% similarity              -0.456227          -0.533481
#               survey 95% similarity              0.694059           0.708197
#               survey PC1                          0.34513           0.361059
#         inter confidence                          52.2105            50.2632
#               consensus                           52.8947            49.0526
#               id                        9oijjTA5XEFzCtedK  2RErnuyZ5YmzTzpxh
#               net spoke 5% similarity           -0.153273         -0.0761383
#               net spoke 95% similarity           0.224151           0.266939
#               net spoke PC1                      0.227144           0.146245
#               spoke 5% similarity               -0.392232          -0.295695
#               spoke 95% similarity                0.68313           0.765869
#               spoke PC1                          0.421066           0.357379
#               survey 5% similarity              -0.522349          -0.314645
#               survey 95% similarity              0.632854           0.783816
#               survey PC1                         0.285709           0.301433
# dodec   indep confidence                          53.8421              52.35
#               consensus                           56.6316              46.55
#               id                        SamzHPveTXj44MS6F  7kcXpJaQqJmx68nYz
#               net spoke 5% similarity          -0.0793694          -0.114197
#               net spoke 95% similarity           0.159772          0.0770877
#               net spoke PC1                      0.101142          0.0358322
#               spoke 5% similarity                -0.17688          -0.080854
#               spoke 95% similarity               0.746125           0.715165
#               spoke PC1                          0.308124           0.309359
#               survey 5% similarity              -0.357902          -0.526161
#               survey 95% similarity               0.58363           0.672679
#               survey PC1                         0.240545           0.384185
#         inter confidence                             55.5              54.45
#               consensus                             56.55              50.45
#               id                        SamzHPveTXj44MS6F  7kcXpJaQqJmx68nYz
#               net spoke 5% similarity           -0.113981         -0.0891296
#               net spoke 95% similarity            0.12637           0.033181
#               net spoke PC1                     0.0688723           0.026976
#               spoke 5% similarity              -0.0644737          -0.179632
#               spoke 95% similarity               0.796651            0.62371
#               spoke PC1                           0.37572           0.231513
#               survey 5% similarity              -0.435877          -0.433635
#               survey 95% similarity              0.547354           0.736951
#               survey PC1                         0.333777           0.290735
#
#                                                        8                  9   \
# caveman indep confidence                            65.85            61.8421
#               consensus                              69.9            61.8421
#               id                        RLNbvyv9ipkrkPJKc  55mC2NYGpS5sYb46x
#               net spoke 5% similarity           -0.123787          -0.121239
#               net spoke 95% similarity           0.377792           0.247501
#               net spoke PC1                      0.230986           0.301755
#               spoke 5% similarity               -0.368662          -0.196553
#               spoke 95% similarity               0.830682            0.83205
#               spoke PC1                          0.422723           0.489493
#               survey 5% similarity              -0.592599          -0.549006
#               survey 95% similarity              0.573904           0.806997
#               survey PC1                         0.448003           0.449991
#         inter confidence                          71.8421            60.8421
#               consensus                                71            54.4211
#               id                        RLNbvyv9ipkrkPJKc  55mC2NYGpS5sYb46x
#               net spoke 5% similarity          -0.0745155         -0.0857499
#               net spoke 95% similarity           0.257403           0.297333
#               net spoke PC1                      0.166784           0.238117
#               spoke 5% similarity               -0.317136          -0.288675
#               spoke 95% similarity               0.692981           0.885615
#               spoke PC1                          0.351911            0.43807
#               survey 5% similarity              -0.536761          -0.599538
#               survey 95% similarity               0.61203           0.715817
#               survey PC1                          0.32208           0.341543
# dodec   indep confidence                             53.7              44.75
#               consensus                              57.3              45.65
#               id                        mYHZ32AyKCmNrfSY5  KtFjB6pDKRispFwCs
#               net spoke 5% similarity          -0.0101608         -0.0917426
#               net spoke 95% similarity           0.012572          0.0446098
#               net spoke PC1                    0.00480489         0.00709574
#               spoke 5% similarity                -0.15414         -0.0312616
#               spoke 95% similarity               0.575471           0.717209
#               spoke PC1                          0.305411           0.272256
#               survey 5% similarity              -0.450313          -0.200025
#               survey 95% similarity              0.651962           0.738633
#               survey PC1                         0.307528           0.284976
#         inter confidence                          73.4444              51.35
#               consensus                           67.5556               50.2
#               id                        mYHZ32AyKCmNrfSY5  KtFjB6pDKRispFwCs
#               net spoke 5% similarity          -0.0200616       -0.000106608
#               net spoke 95% similarity          0.0785495          0.0408459
#               net spoke PC1                     0.0638362          0.0304128
#               spoke 5% similarity               -0.215499         -0.0179635
#               spoke 95% similarity               0.633043           0.679776
#               spoke PC1                           0.28763           0.288224
#               survey 5% similarity              -0.521293          -0.458272
#               survey 95% similarity              0.541936           0.606206
#               survey PC1                         0.418699           0.244487
#
#                                         ...                 20  \
# caveman indep confidence                ...              48.75
#               consensus                 ...              48.35
#               id                        ...  szPuQL8WF5prJP9s7
#               net spoke 5% similarity   ...          -0.105693
#               net spoke 95% similarity  ...           0.404455
#               net spoke PC1             ...           0.250103
#               spoke 5% similarity       ...          -0.369162
#               spoke 95% similarity      ...           0.850287
#               spoke PC1                 ...           0.429961
#               survey 5% similarity      ...          -0.418934
#               survey 95% similarity     ...           0.712926
#               survey PC1                ...           0.352163
#         inter confidence                ...            57.0526
#               consensus                 ...            48.7368
#               id                        ...  szPuQL8WF5prJP9s7
#               net spoke 5% similarity   ...          -0.128349
#               net spoke 95% similarity  ...            0.15681
#               net spoke PC1             ...           0.160837
#               spoke 5% similarity       ...          -0.236984
#               spoke 95% similarity      ...             0.7698
#               spoke PC1                 ...           0.351731
#               survey 5% similarity      ...          -0.494213
#               survey 95% similarity     ...           0.731952
#               survey PC1                ...           0.395654
# dodec   indep confidence                ...              50.55
#               consensus                 ...              58.05
#               id                        ...  dC7qKt8rhj8W3FFTC
#               net spoke 5% similarity   ...          -0.101642
#               net spoke 95% similarity  ...           0.160577
#               net spoke PC1             ...          0.0481497
#               spoke 5% similarity       ...          -0.216229
#               spoke 95% similarity      ...           0.710163
#               spoke PC1                 ...           0.271441
#               survey 5% similarity      ...          -0.405171
#               survey 95% similarity     ...           0.723924
#               survey PC1                ...           0.312245
#         inter confidence                ...              48.25
#               consensus                 ...               50.6
#               id                        ...  dC7qKt8rhj8W3FFTC
#               net spoke 5% similarity   ...          0.0124574
#               net spoke 95% similarity  ...           0.043159
#               net spoke PC1             ...          0.0330651
#               spoke 5% similarity       ...          -0.131348
#               spoke 95% similarity      ...           0.636786
#               spoke PC1                 ...           0.224407
#               survey 5% similarity      ...          -0.414776
#               survey 95% similarity     ...           0.671002
#               survey PC1                ...           0.320902
#
#                                                        21                 22  \
# caveman indep confidence                            42.75              50.25
#               consensus                             48.85               55.3
#               id                        HXeLe9DnXEMs6JFjf  ew8uue7goY6SzSnMn
#               net spoke 5% similarity           -0.113519          -0.144279
#               net spoke 95% similarity           0.187846           0.147854
#               net spoke PC1                      0.188644           0.174049
#               spoke 5% similarity                -0.32015          -0.185634
#               spoke 95% similarity               0.698674           0.762401
#               spoke PC1                          0.370795           0.389353
#               survey 5% similarity               -0.44806          -0.445848
#               survey 95% similarity              0.669814           0.707986
#               survey PC1                         0.365753           0.378361
#         inter confidence                            59.35            54.8947
#               consensus                              57.4            48.6842
#               id                        HXeLe9DnXEMs6JFjf  ew8uue7goY6SzSnMn
#               net spoke 5% similarity          -0.0731375          -0.111852
#               net spoke 95% similarity           0.342903            0.27201
#               net spoke PC1                       0.14858           0.170759
#               spoke 5% similarity               -0.352712          -0.354242
#               spoke 95% similarity               0.745203           0.750501
#               spoke PC1                          0.322903           0.365624
#               survey 5% similarity              -0.637668          -0.383117
#               survey 95% similarity              0.660915           0.642283
#               survey PC1                         0.310268           0.318905
# dodec   indep confidence                          51.8947            63.8824
#               consensus                           46.7368            59.3529
#               id                        nkPob7gypQi6DtwqS  F6g9NDczqP966pA5m
#               net spoke 5% similarity          -0.0607848          -0.134727
#               net spoke 95% similarity          0.0865395           0.153086
#               net spoke PC1                     0.0500432           0.133998
#               spoke 5% similarity               0.0255655          -0.306786
#               spoke 95% similarity               0.834018           0.634486
#               spoke PC1                           0.28496           0.404842
#               survey 5% similarity              -0.413678          -0.522013
#               survey 95% similarity              0.695285           0.492073
#               survey PC1                         0.261946           0.377682
#         inter confidence                            52.65            61.4211
#               consensus                              56.8            54.6842
#               id                        nkPob7gypQi6DtwqS  F6g9NDczqP966pA5m
#               net spoke 5% similarity          -0.0864647          -0.100551
#               net spoke 95% similarity           0.131642            0.14372
#               net spoke PC1                     0.0790775           0.057134
#               spoke 5% similarity               -0.244797          -0.326482
#               spoke 95% similarity               0.688088           0.625303
#               spoke PC1                          0.273245           0.297049
#               survey 5% similarity              -0.337764          -0.461588
#               survey 95% similarity              0.718046           0.561012
#               survey PC1                         0.267995           0.404306
#
#                                                        23                 24  \
# caveman indep confidence                          48.8421            57.6842
#               consensus                           52.1053            57.8947
#               id                        To5RB7JuNk4h5FHaZ  W4EAr6TwRFApoCagP
#               net spoke 5% similarity            -0.16022          -0.213953
#               net spoke 95% similarity           0.331898           0.204357
#               net spoke PC1                      0.187399           0.259929
#               spoke 5% similarity                -0.39734          -0.332106
#               spoke 95% similarity               0.793884           0.793884
#               spoke PC1                          0.375183           0.453819
#               survey 5% similarity              -0.605129          -0.530969
#               survey 95% similarity              0.632516           0.764925
#               survey PC1                         0.372048           0.505063
#         inter confidence                             62.6               63.6
#               consensus                             57.55               60.5
#               id                        To5RB7JuNk4h5FHaZ  W4EAr6TwRFApoCagP
#               net spoke 5% similarity           -0.129034           -0.20133
#               net spoke 95% similarity           0.282219           0.179042
#               net spoke PC1                      0.188677           0.249354
#               spoke 5% similarity               -0.384297          -0.250743
#               spoke 95% similarity               0.714941           0.809277
#               spoke PC1                           0.37941           0.448488
#               survey 5% similarity               -0.46536          -0.532295
#               survey 95% similarity              0.574238           0.797072
#               survey PC1                         0.351894           0.402275
# dodec   indep confidence                             57.4              42.15
#               consensus                             53.25              45.95
#               id                        7c9biMCakuPCxMEXN  T9KCzCFiibi6W5mnL
#               net spoke 5% similarity          -0.0849207          -0.113577
#               net spoke 95% similarity           0.151765           0.128401
#               net spoke PC1                      0.116048          0.0869219
#               spoke 5% similarity               -0.268494          -0.133835
#               spoke 95% similarity               0.641263           0.719363
#               spoke PC1                          0.310252           0.307615
#               survey 5% similarity              -0.455432          -0.456815
#               survey 95% similarity              0.621228           0.735932
#               survey PC1                         0.316405            0.28661
#         inter confidence                          53.2778              40.65
#               consensus                           52.5556              50.95
#               id                        7c9biMCakuPCxMEXN  T9KCzCFiibi6W5mnL
#               net spoke 5% similarity           -0.027072          -0.101418
#               net spoke 95% similarity           0.189242          0.0988248
#               net spoke PC1                     0.0943949          0.0694862
#               spoke 5% similarity               -0.271448          -0.352112
#               spoke 95% similarity               0.644438           0.542904
#               spoke PC1                          0.314078           0.271567
#               survey 5% similarity               -0.47036          -0.441446
#               survey 95% similarity              0.626741           0.570671
#               survey PC1                         0.313919           0.258817
#
#                                                        25                 26  \
# caveman indep confidence                             54.7               50.4
#               consensus                             54.95               56.5
#               id                        zg5puDzKGCxk7wAj2  W7ZjgcCnPfhq8eYnp
#               net spoke 5% similarity           -0.240105          -0.101134
#               net spoke 95% similarity           0.245934           0.163909
#               net spoke PC1                      0.161938          0.0882085
#               spoke 5% similarity               -0.354044          -0.114092
#               spoke 95% similarity               0.801265           0.787037
#               spoke PC1                          0.343516           0.282689
#               survey 5% similarity              -0.382967          -0.299744
#               survey 95% similarity               0.69992           0.783079
#               survey PC1                         0.312625           0.315697
#         inter confidence                             52.7            60.1111
#               consensus                              57.8            53.4444
#               id                        zg5puDzKGCxk7wAj2  W7ZjgcCnPfhq8eYnp
#               net spoke 5% similarity           -0.126979         -0.0755266
#               net spoke 95% similarity           0.185789           0.394467
#               net spoke PC1                       0.12903           0.156595
#               spoke 5% similarity               -0.288675          -0.332106
#               spoke 95% similarity               0.745474           0.853447
#               spoke PC1                          0.318092           0.349459
#               survey 5% similarity              -0.365703          -0.518493
#               survey 95% similarity              0.738899           0.689538
#               survey PC1                         0.353803           0.316824
# dodec   indep confidence                             52.1            55.0526
#               consensus                             58.15            60.6316
#               id                        aS5rH5N5tnRsr3CQQ  RugWRCuQ9MounHF8x
#               net spoke 5% similarity           0.0119093          -0.147624
#               net spoke 95% similarity          0.0056507           0.125429
#               net spoke PC1                   -0.00427295          0.0621269
#               spoke 5% similarity               0.0115045          -0.302186
#               spoke 95% similarity               0.651795           0.647414
#               spoke PC1                           0.21534           0.297126
#               survey 5% similarity              -0.332867          -0.377371
#               survey 95% similarity              0.723949           0.737751
#               survey PC1                         0.253474           0.332346
#         inter confidence                             64.4              52.45
#               consensus                             63.95               46.2
#               id                        aS5rH5N5tnRsr3CQQ  RugWRCuQ9MounHF8x
#               net spoke 5% similarity          -0.0649216         -0.0727439
#               net spoke 95% similarity            0.11633          0.0778493
#               net spoke PC1                     0.0124595           0.061643
#               spoke 5% similarity               -0.178571          -0.182875
#               spoke 95% similarity                0.63897           0.681687
#               spoke PC1                          0.322895             0.3114
#               survey 5% similarity              -0.426027          -0.488307
#               survey 95% similarity               0.66755           0.801166
#               survey PC1                         0.364267           0.319372
#
#                                                        27                 28  \
# caveman indep confidence                            52.75            64.3889
#               consensus                             52.25            64.9444
#               id                        PRBmQFw8WDcrNi2Qn  wx5E4WNYAzhggxxNt
#               net spoke 5% similarity           -0.106047          -0.118957
#               net spoke 95% similarity           0.105154           0.227559
#               net spoke PC1                      0.131706           0.252387
#               spoke 5% similarity              -0.0300367          -0.301073
#               spoke 95% similarity               0.823839              0.742
#               spoke PC1                          0.357237           0.454266
#               survey 5% similarity              -0.454362          -0.484487
#               survey 95% similarity              0.681185           0.682026
#               survey PC1                         0.341005            0.41059
#         inter confidence                               51              61.55
#               consensus                             49.45              57.35
#               id                        PRBmQFw8WDcrNi2Qn  wx5E4WNYAzhggxxNt
#               net spoke 5% similarity           -0.117578          -0.175909
#               net spoke 95% similarity           0.261238           0.370055
#               net spoke PC1                      0.195526           0.272165
#               spoke 5% similarity               -0.330623          -0.428295
#               spoke 95% similarity               0.765466           0.802839
#               spoke PC1                          0.429016           0.470787
#               survey 5% similarity              -0.556914          -0.674078
#               survey 95% similarity               0.64202           0.703062
#               survey PC1                         0.332883           0.475225
# dodec   indep confidence                          42.8947            54.8947
#               consensus                                50            54.9474
#               id                        ig8z4GCN3uW4nFT54  hjTbDvCzT2RW9pgm8
#               net spoke 5% similarity          -0.0725135          -0.155915
#               net spoke 95% similarity           0.174572           0.111817
#               net spoke PC1                     0.0901392          0.0409523
#               spoke 5% similarity               -0.231032          -0.311549
#               spoke 95% similarity               0.734811           0.652288
#               spoke PC1                          0.286818           0.269504
#               survey 5% similarity              -0.452416          -0.362983
#               survey 95% similarity               0.61026           0.657625
#               survey PC1                         0.274822           0.290573
#         inter confidence                          40.5789              65.35
#               consensus                                47               65.6
#               id                        ig8z4GCN3uW4nFT54  hjTbDvCzT2RW9pgm8
#               net spoke 5% similarity           -0.174323        -0.00860594
#               net spoke 95% similarity           0.308903           0.130236
#               net spoke PC1                      0.227491          0.0381685
#               spoke 5% similarity               -0.363809           -0.25634
#               spoke 95% similarity               0.896421           0.587616
#               spoke PC1                          0.433176           0.221859
#               survey 5% similarity              -0.526273           -0.46451
#               survey 95% similarity              0.688929           0.592063
#               survey PC1                         0.450064           0.340722
#
#                                                        29
# caveman indep confidence                            61.25
#               consensus                              63.6
#               id                        R5JmsFyk7arzZrwiE
#               net spoke 5% similarity          -0.0979508
#               net spoke 95% similarity            0.18726
#               net spoke PC1                      0.110225
#               spoke 5% similarity               -0.129046
#               spoke 95% similarity               0.793361
#               spoke PC1                          0.400555
#               survey 5% similarity              -0.464423
#               survey 95% similarity              0.578193
#               survey PC1                         0.402418
#         inter confidence                             60.4
#               consensus                             58.45
#               id                        R5JmsFyk7arzZrwiE
#               net spoke 5% similarity           -0.178203
#               net spoke 95% similarity           0.255909
#               net spoke PC1                      0.171188
#               spoke 5% similarity               -0.355311
#               spoke 95% similarity               0.793884
#               spoke PC1                          0.348154
#               survey 5% similarity              -0.477525
#               survey 95% similarity              0.613346
#               survey PC1                         0.287303
# dodec   indep confidence                             59.1
#               consensus                             64.15
#               id                        d2N6gipGzAM2B3GPn
#               net spoke 5% similarity           -0.045669
#               net spoke 95% similarity           0.165532
#               net spoke PC1                      0.097031
#               spoke 5% similarity               -0.184017
#               spoke 95% similarity               0.690066
#               spoke PC1                          0.394813
#               survey 5% similarity               -0.47493
#               survey 95% similarity              0.638807
#               survey PC1                          0.33135
#         inter confidence                             53.1
#               consensus                              57.6
#               id                        d2N6gipGzAM2B3GPn
#               net spoke 5% similarity           -0.242674
#               net spoke 95% similarity            0.19747
#               net spoke PC1                      0.232882
#               spoke 5% similarity               -0.297355
#               spoke 95% similarity                0.82102
#               spoke PC1                          0.435931
#               survey 5% similarity              -0.384434
#               survey 95% similarity              0.747499
#               survey PC1                         0.426932
#
# [48 rows x 30 columns]

# %%
measurements.to_pickle(output_dir+"end_of_game_measurements_block.pickle")

# %%
measurements = pd.read_pickle(output_dir+"end_of_game_measurements_block.pickle")

# %%
# write a flat output file for the games, to be used in mediation analysis
measurements_flat = measurements.unstack(level=[0,1])
measurements_flat.loc['t'] = [1 if c[2]=="inter" else 0 for c in measurements_flat.columns]
measurements_flat.loc['network'] = [1 if c[1]=="caveman" else 0 for c in measurements_flat.columns]
measurements_flat.columns = ["GT_" + str(measurements_flat.loc['id'][c]) + ("_1" if c[2]=="inter" else "_0") for c in measurements_flat.columns]
measurements_flat.T.to_csv(output_dir+"end_of_game_measurements.csv")
measurements_flat.T
# Out:
#                        confidence consensus                 id  \
# GT_jcfFiGC22Api8cm7o_0    60.7368   58.2632  jcfFiGC22Api8cm7o
# GT_jcfFiGC22Api8cm7o_1       54.8     53.35  jcfFiGC22Api8cm7o
# GT_Lj2up2ePZA6WtiK4q_0         53   48.7895  Lj2up2ePZA6WtiK4q
# GT_Lj2up2ePZA6WtiK4q_1       55.1     49.95  Lj2up2ePZA6WtiK4q
# GT_oWf8QrmFrj8ZiE6JK_0    58.9474   64.5789  oWf8QrmFrj8ZiE6JK
# ...                           ...       ...                ...
# GT_hjTbDvCzT2RW9pgm8_1      65.35      65.6  hjTbDvCzT2RW9pgm8
# GT_R5JmsFyk7arzZrwiE_0      61.25      63.6  R5JmsFyk7arzZrwiE
# GT_R5JmsFyk7arzZrwiE_1       60.4     58.45  R5JmsFyk7arzZrwiE
# GT_d2N6gipGzAM2B3GPn_0       59.1     64.15  d2N6gipGzAM2B3GPn
# GT_d2N6gipGzAM2B3GPn_1       53.1      57.6  d2N6gipGzAM2B3GPn
#
#                        net spoke 5% similarity net spoke 95% similarity  \
# GT_jcfFiGC22Api8cm7o_0               -0.109421                 0.173093
# GT_jcfFiGC22Api8cm7o_1               -0.051287                 0.188156
# GT_Lj2up2ePZA6WtiK4q_0               -0.135912                0.0961384
# GT_Lj2up2ePZA6WtiK4q_1               -0.088976                 0.153019
# GT_oWf8QrmFrj8ZiE6JK_0              -0.0464853                 0.399166
# ...                                        ...                      ...
# GT_hjTbDvCzT2RW9pgm8_1             -0.00942991                 0.130742
# GT_R5JmsFyk7arzZrwiE_0               -0.104817                 0.183853
# GT_R5JmsFyk7arzZrwiE_1               -0.183742                 0.254854
# GT_d2N6gipGzAM2B3GPn_0              -0.0506744                  0.16707
# GT_d2N6gipGzAM2B3GPn_1               -0.241628                 0.200066
#
#                        net spoke PC1 spoke 5% similarity spoke 95% similarity  \
# GT_jcfFiGC22Api8cm7o_0      0.167596           -0.267283             0.770833
# GT_jcfFiGC22Api8cm7o_1      0.147737           -0.243468             0.770392
# GT_Lj2up2ePZA6WtiK4q_0     0.0444583            -0.11606             0.748331
# GT_Lj2up2ePZA6WtiK4q_1     0.0876056            -0.26717             0.677797
# GT_oWf8QrmFrj8ZiE6JK_0      0.213104           -0.271448             0.906105
# ...                              ...                 ...                  ...
# GT_hjTbDvCzT2RW9pgm8_1     0.0384105            -0.25634             0.587616
# GT_R5JmsFyk7arzZrwiE_0      0.110823           -0.129046             0.793361
# GT_R5JmsFyk7arzZrwiE_1      0.169985           -0.355311             0.793884
# GT_d2N6gipGzAM2B3GPn_0     0.0947598           -0.184017             0.690066
# GT_d2N6gipGzAM2B3GPn_1      0.236377           -0.297355              0.82102
#
#                        spoke PC1 survey 5% similarity survey 95% similarity  \
# GT_jcfFiGC22Api8cm7o_0  0.356007            -0.480858              0.577215
# GT_jcfFiGC22Api8cm7o_1  0.338543            -0.307725              0.832922
# GT_Lj2up2ePZA6WtiK4q_0  0.276937            -0.415275               0.78428
# GT_Lj2up2ePZA6WtiK4q_1  0.286886            -0.487964              0.620877
# GT_oWf8QrmFrj8ZiE6JK_0  0.392184            -0.465191               0.63842
# ...                          ...                  ...                   ...
# GT_hjTbDvCzT2RW9pgm8_1  0.221859             -0.46451              0.592063
# GT_R5JmsFyk7arzZrwiE_0  0.400555            -0.464423              0.578193
# GT_R5JmsFyk7arzZrwiE_1  0.348154            -0.477525              0.613346
# GT_d2N6gipGzAM2B3GPn_0  0.394813             -0.47493              0.638807
# GT_d2N6gipGzAM2B3GPn_1  0.435931            -0.384434              0.747499
#
#                        survey PC1  t network
# GT_jcfFiGC22Api8cm7o_0   0.285638  0       1
# GT_jcfFiGC22Api8cm7o_1   0.330469  1       1
# GT_Lj2up2ePZA6WtiK4q_0   0.280021  0       0
# GT_Lj2up2ePZA6WtiK4q_1   0.328971  1       0
# GT_oWf8QrmFrj8ZiE6JK_0   0.435887  0       1
# ...                           ... ..     ...
# GT_hjTbDvCzT2RW9pgm8_1   0.340722  1       0
# GT_R5JmsFyk7arzZrwiE_0   0.402418  0       1
# GT_R5JmsFyk7arzZrwiE_1   0.287303  1       1
# GT_d2N6gipGzAM2B3GPn_0    0.33135  0       0
# GT_d2N6gipGzAM2B3GPn_1   0.426932  1       0
#
# [120 rows x 14 columns]

# %%
# todo: drop id row for subsequent analysis
measurements.drop('id', level=2, inplace=True)
measurements.index = measurements.index.remove_unused_levels()

# %%
def bootstrap_mean(l, q=(5, 95), n=1000):
    "Basic bootstrap confidence intervals (q) with n resamples"
    # use 90% CI so that the cutoff corresponds to p <.05 in one-sided T test
    return np.percentile([np.mean(np.random.choice(l, size=len(l))) for _ in range(n)], q=q)


def mean_result(measure1, _):
    return measure1.mean()

def mean_lowerbound(measure1, _):
    return bootstrap_mean(measure1)[0]

def mean_upperbound(measure1, _):
    return bootstrap_mean(measure1)[1]

def effect_size(measure1, measure2):
    return (measure1 - measure2).mean()

def effect_lowerbound(measure1, measure2):
    return bootstrap_mean(measure1 - measure2)[0]

def effect_upperbound(measure1, measure2):
    return bootstrap_mean(measure1 - measure2)[1]

def effect_p_val(measure1, measure2):
    return stats.ttest_rel(measure1, measure2)[1]

def effect_p_val_one_tail(measure1, measure2):
    return stats.ttest_rel(measure1, measure2)[1]/2

def make_table(measurements, func, network='dodec', treatment='indep'):
    rows = measurements.index.levels[2]
    cols = np.unique(measurements.index.droplevel(2))
    res = pd.DataFrame(index=rows, columns=cols)
    for row in rows:
        for col in cols:
            comparison = measurements.loc[col+tuple([row])].dropna()
            #reference = measurements.loc[('dodec', 'indep')+tuple([row])][comparison.index]
            reference = measurements.loc[(network, treatment)+tuple([row])][comparison.index]
            res.at[row, col] = func(comparison, reference)
    return res

# %%
res = make_table(measurements, mean_result)
res
# Out:
#                          (caveman, indep) (caveman, inter) (dodec, indep)  \
# confidence                        56.0755          59.1306        55.3935
# consensus                         57.6475           56.931        55.8923
# net spoke 5% similarity         -0.115199        -0.111787      -0.081649
# net spoke 95% similarity         0.253323         0.255335      0.0961719
# net spoke PC1                     0.19011          0.19404      0.0534794
# spoke 5% similarity             -0.271291        -0.303028      -0.157664
# spoke 95% similarity             0.803906         0.777318        0.68817
# spoke PC1                        0.387681         0.391874       0.296064
# survey 5% similarity            -0.497605        -0.491553      -0.408854
# survey 95% similarity            0.689841         0.704249       0.668364
# survey PC1                       0.380187         0.362617       0.308066
#
#                          (dodec, inter)
# confidence                      57.5618
# consensus                       55.2684
# net spoke 5% similarity      -0.0712217
# net spoke 95% similarity       0.121914
# net spoke PC1                 0.0748206
# spoke 5% similarity           -0.215429
# spoke 95% similarity           0.672197
# spoke PC1                      0.292582
# survey 5% similarity           -0.44298
# survey 95% similarity          0.664479
# survey PC1                     0.336152

# %%
res_lowerbound = make_table(measurements, mean_lowerbound)
res_lowerbound
# Out:
#                          (caveman, indep) (caveman, inter) (dodec, indep)  \
# confidence                        54.5227          57.6118        53.3665
# consensus                         56.1138          55.3053        54.1546
# net spoke 5% similarity         -0.131451        -0.127078     -0.0935929
# net spoke 95% similarity         0.229759         0.233353       0.080823
# net spoke PC1                    0.174641         0.177167      0.0427488
# spoke 5% similarity             -0.301361        -0.329362      -0.186562
# spoke 95% similarity             0.787882         0.759451       0.671173
# spoke PC1                        0.372614         0.374795       0.281489
# survey 5% similarity             -0.52336        -0.523878      -0.432917
# survey 95% similarity             0.67001         0.680504       0.648751
# survey PC1                       0.362474         0.346118       0.292744
#
#                          (dodec, inter)
# confidence                      55.0749
# consensus                       53.1088
# net spoke 5% similarity      -0.0897504
# net spoke 95% similarity       0.104355
# net spoke PC1                 0.0613637
# spoke 5% similarity            -0.24312
# spoke 95% similarity           0.649878
# spoke PC1                       0.27611
# survey 5% similarity          -0.464038
# survey 95% similarity          0.641974
# survey PC1                     0.320389

# %%
res_upperbound = make_table(measurements, mean_upperbound)
res_upperbound
# Out:
#                          (caveman, indep) (caveman, inter) (dodec, indep)  \
# confidence                        57.6594          60.6332        57.2807
# consensus                         59.2462          58.5796        57.5502
# net spoke 5% similarity        -0.0998198       -0.0960107     -0.0690618
# net spoke 95% similarity         0.277272         0.277346       0.112024
# net spoke PC1                    0.205675         0.211197      0.0648191
# spoke 5% similarity             -0.239795        -0.271104      -0.124849
# spoke 95% similarity              0.81942         0.795017       0.704569
# spoke PC1                        0.402959           0.4108       0.309388
# survey 5% similarity            -0.470746        -0.457351      -0.385043
# survey 95% similarity             0.70945          0.72893       0.689818
# survey PC1                       0.400242         0.380586         0.3244
#
#                          (dodec, inter)
# confidence                      59.9384
# consensus                       57.1346
# net spoke 5% similarity      -0.0561665
# net spoke 95% similarity       0.140271
# net spoke PC1                 0.0925214
# spoke 5% similarity           -0.188938
# spoke 95% similarity           0.695965
# spoke PC1                      0.309164
# survey 5% similarity          -0.422233
# survey 95% similarity          0.685256
# survey PC1                     0.353003

# %%
eff = make_table(measurements, effect_size)
eff
# Out:
#                          (caveman, indep) (caveman, inter) (dodec, indep)  \
# confidence                       0.681974           3.7371              0
# consensus                         1.75515           1.0387              0
# net spoke 5% similarity        -0.0335497       -0.0301381              0
# net spoke 95% similarity         0.157151         0.159163              0
# net spoke PC1                     0.13663         0.140561              0
# spoke 5% similarity             -0.113627        -0.145364              0
# spoke 95% similarity             0.115736        0.0891476              0
# spoke PC1                       0.0916162        0.0958095              0
# survey 5% similarity           -0.0887504       -0.0826988              0
# survey 95% similarity           0.0214769        0.0358843              0
# survey PC1                      0.0721204        0.0545508              0
#
#                          (dodec, inter)
# confidence                      2.16832
# consensus                     -0.623904
# net spoke 5% similarity       0.0104272
# net spoke 95% similarity      0.0257418
# net spoke PC1                 0.0213412
# spoke 5% similarity           -0.057765
# spoke 95% similarity          -0.015973
# spoke PC1                   -0.00348228
# survey 5% similarity         -0.0341256
# survey 95% similarity       -0.00388585
# survey PC1                    0.0280852

# %%
eff_pval = make_table(measurements.dropna(axis=1), effect_p_val_one_tail)
eff_pval
# Out:
#                          (caveman, indep) (caveman, inter) (dodec, indep)  \
# confidence                       0.322673        0.0119632            NaN
# consensus                       0.0868613         0.230841            NaN
# net spoke 5% similarity        0.00431647        0.0100232            NaN
# net spoke 95% similarity      1.17061e-09      1.51439e-11            NaN
# net spoke PC1                 2.07486e-11      2.79771e-12            NaN
# spoke 5% similarity           6.62032e-05      8.12011e-08            NaN
# spoke 95% similarity          2.09443e-09      7.13514e-08            NaN
# spoke PC1                     1.86737e-08      1.83911e-07            NaN
# survey 5% similarity          6.34841e-05       0.00147917            NaN
# survey 95% similarity            0.123006       0.00581763            NaN
# survey PC1                     2.3193e-05      0.000346284            NaN
#
#                          (dodec, inter)
# confidence                    0.0451382
# consensus                      0.311086
# net spoke 5% similarity        0.217349
# net spoke 95% similarity      0.0149721
# net spoke PC1                 0.0163474
# spoke 5% similarity          0.00459607
# spoke 95% similarity           0.167968
# spoke PC1                      0.389573
# survey 5% similarity          0.0583438
# survey 95% similarity            0.4137
# survey PC1                    0.0216648

# %%
eff_lowerbound = make_table(measurements, effect_lowerbound)
eff_lowerbound
# Out:
#                          (caveman, indep) (caveman, inter) (dodec, indep)  \
# confidence                       -1.50542          1.35703              0
# consensus                       -0.364096         -1.18458              0
# net spoke 5% similarity        -0.0535672       -0.0487696              0
# net spoke 95% similarity         0.125858         0.133753              0
# net spoke PC1                    0.115025          0.12069              0
# spoke 5% similarity             -0.156118        -0.179943              0
# spoke 95% similarity            0.0941977        0.0681765              0
# spoke PC1                       0.0726827        0.0722027              0
# survey 5% similarity            -0.123563        -0.121184              0
# survey 95% similarity         -0.00989399        0.0148081              0
# survey PC1                       0.048142        0.0311023              0
#
#                          (dodec, inter)
# confidence                     0.201013
# consensus                      -2.72917
# net spoke 5% similarity      -0.0122932
# net spoke 95% similarity     0.00831233
# net spoke PC1                0.00606257
# spoke 5% similarity          -0.0912665
# spoke 95% similarity         -0.0429629
# spoke PC1                     -0.023995
# survey 5% similarity          -0.066697
# survey 95% similarity        -0.0309731
# survey PC1                   0.00572616

# %%
eff_upperbound = make_table(measurements, effect_upperbound)
eff_upperbound
# Out:
#                          (caveman, indep) (caveman, inter) (dodec, indep)  \
# confidence                        3.37837          6.34561              0
# consensus                         3.95755          3.30224              0
# net spoke 5% similarity        -0.0156653       -0.0102208              0
# net spoke 95% similarity         0.185778         0.183336              0
# net spoke PC1                    0.158771         0.161156              0
# spoke 5% similarity            -0.0716404        -0.111149              0
# spoke 95% similarity             0.139116           0.1102              0
# spoke PC1                        0.110747         0.121812              0
# survey 5% similarity            -0.057349       -0.0402451              0
# survey 95% similarity           0.0505189        0.0581066              0
# survey PC1                      0.0977279        0.0763352              0
#
#                          (dodec, inter)
# confidence                      4.33592
# consensus                       1.34796
# net spoke 5% similarity       0.0316691
# net spoke 95% similarity      0.0445638
# net spoke PC1                 0.0372118
# spoke 5% similarity          -0.0228827
# spoke 95% similarity         0.00960816
# spoke PC1                     0.0170701
# survey 5% similarity         0.00153168
# survey 95% similarity         0.0226752
# survey PC1                    0.0502952

# %%
export_table = pd.DataFrame()
export_table["Result Mean"] = res.unstack()
export_table["Result Lower Bound"] = res_lowerbound.unstack()
export_table["Result Upper Bound"] = res_upperbound.unstack()
export_table["Effect Size"] = eff.unstack()
export_table["Effect Upper Bound"] = eff_upperbound.unstack()
export_table["Effect Lower Bound"] = eff_lowerbound.unstack()
export_table["Effect P Value"] = eff_pval.unstack()


export_table.to_csv(output_dir+"end_of_game_effects_summary.csv")
export_table
# Out:
#                                           Result Mean Result Lower Bound  \
# (caveman, indep) confidence                   56.0755            54.5227
#                  consensus                    57.6475            56.1138
#                  net spoke 5% similarity    -0.115199          -0.131451
#                  net spoke 95% similarity    0.253323           0.229759
#                  net spoke PC1                0.19011           0.174641
#                  spoke 5% similarity        -0.271291          -0.301361
#                  spoke 95% similarity        0.803906           0.787882
#                  spoke PC1                   0.387681           0.372614
#                  survey 5% similarity       -0.497605           -0.52336
#                  survey 95% similarity       0.689841            0.67001
#                  survey PC1                  0.380187           0.362474
# (caveman, inter) confidence                   59.1306            57.6118
#                  consensus                     56.931            55.3053
#                  net spoke 5% similarity    -0.111787          -0.127078
#                  net spoke 95% similarity    0.255335           0.233353
#                  net spoke PC1                0.19404           0.177167
#                  spoke 5% similarity        -0.303028          -0.329362
#                  spoke 95% similarity        0.777318           0.759451
#                  spoke PC1                   0.391874           0.374795
#                  survey 5% similarity       -0.491553          -0.523878
#                  survey 95% similarity       0.704249           0.680504
#                  survey PC1                  0.362617           0.346118
# (dodec, indep)   confidence                   55.3935            53.3665
#                  consensus                    55.8923            54.1546
#                  net spoke 5% similarity    -0.081649         -0.0935929
#                  net spoke 95% similarity   0.0961719           0.080823
#                  net spoke PC1              0.0534794          0.0427488
#                  spoke 5% similarity        -0.157664          -0.186562
#                  spoke 95% similarity         0.68817           0.671173
#                  spoke PC1                   0.296064           0.281489
#                  survey 5% similarity       -0.408854          -0.432917
#                  survey 95% similarity       0.668364           0.648751
#                  survey PC1                  0.308066           0.292744
# (dodec, inter)   confidence                   57.5618            55.0749
#                  consensus                    55.2684            53.1088
#                  net spoke 5% similarity   -0.0712217         -0.0897504
#                  net spoke 95% similarity    0.121914           0.104355
#                  net spoke PC1              0.0748206          0.0613637
#                  spoke 5% similarity        -0.215429           -0.24312
#                  spoke 95% similarity        0.672197           0.649878
#                  spoke PC1                   0.292582            0.27611
#                  survey 5% similarity        -0.44298          -0.464038
#                  survey 95% similarity       0.664479           0.641974
#                  survey PC1                  0.336152           0.320389
#
#                                           Result Upper Bound Effect Size  \
# (caveman, indep) confidence                          57.6594    0.681974
#                  consensus                           59.2462     1.75515
#                  net spoke 5% similarity          -0.0998198  -0.0335497
#                  net spoke 95% similarity           0.277272    0.157151
#                  net spoke PC1                      0.205675     0.13663
#                  spoke 5% similarity               -0.239795   -0.113627
#                  spoke 95% similarity                0.81942    0.115736
#                  spoke PC1                          0.402959   0.0916162
#                  survey 5% similarity              -0.470746  -0.0887504
#                  survey 95% similarity               0.70945   0.0214769
#                  survey PC1                         0.400242   0.0721204
# (caveman, inter) confidence                          60.6332      3.7371
#                  consensus                           58.5796      1.0387
#                  net spoke 5% similarity          -0.0960107  -0.0301381
#                  net spoke 95% similarity           0.277346    0.159163
#                  net spoke PC1                      0.211197    0.140561
#                  spoke 5% similarity               -0.271104   -0.145364
#                  spoke 95% similarity               0.795017   0.0891476
#                  spoke PC1                            0.4108   0.0958095
#                  survey 5% similarity              -0.457351  -0.0826988
#                  survey 95% similarity               0.72893   0.0358843
#                  survey PC1                         0.380586   0.0545508
# (dodec, indep)   confidence                          57.2807           0
#                  consensus                           57.5502           0
#                  net spoke 5% similarity          -0.0690618           0
#                  net spoke 95% similarity           0.112024           0
#                  net spoke PC1                     0.0648191           0
#                  spoke 5% similarity               -0.124849           0
#                  spoke 95% similarity               0.704569           0
#                  spoke PC1                          0.309388           0
#                  survey 5% similarity              -0.385043           0
#                  survey 95% similarity              0.689818           0
#                  survey PC1                           0.3244           0
# (dodec, inter)   confidence                          59.9384     2.16832
#                  consensus                           57.1346   -0.623904
#                  net spoke 5% similarity          -0.0561665   0.0104272
#                  net spoke 95% similarity           0.140271   0.0257418
#                  net spoke PC1                     0.0925214   0.0213412
#                  spoke 5% similarity               -0.188938   -0.057765
#                  spoke 95% similarity               0.695965   -0.015973
#                  spoke PC1                          0.309164 -0.00348228
#                  survey 5% similarity              -0.422233  -0.0341256
#                  survey 95% similarity              0.685256 -0.00388585
#                  survey PC1                         0.353003   0.0280852
#
#                                           Effect Upper Bound  \
# (caveman, indep) confidence                          3.37837
#                  consensus                           3.95755
#                  net spoke 5% similarity          -0.0156653
#                  net spoke 95% similarity           0.185778
#                  net spoke PC1                      0.158771
#                  spoke 5% similarity              -0.0716404
#                  spoke 95% similarity               0.139116
#                  spoke PC1                          0.110747
#                  survey 5% similarity              -0.057349
#                  survey 95% similarity             0.0505189
#                  survey PC1                        0.0977279
# (caveman, inter) confidence                          6.34561
#                  consensus                           3.30224
#                  net spoke 5% similarity          -0.0102208
#                  net spoke 95% similarity           0.183336
#                  net spoke PC1                      0.161156
#                  spoke 5% similarity               -0.111149
#                  spoke 95% similarity                 0.1102
#                  spoke PC1                          0.121812
#                  survey 5% similarity             -0.0402451
#                  survey 95% similarity             0.0581066
#                  survey PC1                        0.0763352
# (dodec, indep)   confidence                                0
#                  consensus                                 0
#                  net spoke 5% similarity                   0
#                  net spoke 95% similarity                  0
#                  net spoke PC1                             0
#                  spoke 5% similarity                       0
#                  spoke 95% similarity                      0
#                  spoke PC1                                 0
#                  survey 5% similarity                      0
#                  survey 95% similarity                     0
#                  survey PC1                                0
# (dodec, inter)   confidence                          4.33592
#                  consensus                           1.34796
#                  net spoke 5% similarity           0.0316691
#                  net spoke 95% similarity          0.0445638
#                  net spoke PC1                     0.0372118
#                  spoke 5% similarity              -0.0228827
#                  spoke 95% similarity             0.00960816
#                  spoke PC1                         0.0170701
#                  survey 5% similarity             0.00153168
#                  survey 95% similarity             0.0226752
#                  survey PC1                        0.0502952
#
#                                           Effect Lower Bound Effect P Value
# (caveman, indep) confidence                         -1.50542       0.322673
#                  consensus                         -0.364096      0.0868613
#                  net spoke 5% similarity          -0.0535672     0.00431647
#                  net spoke 95% similarity           0.125858    1.17061e-09
#                  net spoke PC1                      0.115025    2.07486e-11
#                  spoke 5% similarity               -0.156118    6.62032e-05
#                  spoke 95% similarity              0.0941977    2.09443e-09
#                  spoke PC1                         0.0726827    1.86737e-08
#                  survey 5% similarity              -0.123563    6.34841e-05
#                  survey 95% similarity           -0.00989399       0.123006
#                  survey PC1                         0.048142     2.3193e-05
# (caveman, inter) confidence                          1.35703      0.0119632
#                  consensus                          -1.18458       0.230841
#                  net spoke 5% similarity          -0.0487696      0.0100232
#                  net spoke 95% similarity           0.133753    1.51439e-11
#                  net spoke PC1                       0.12069    2.79771e-12
#                  spoke 5% similarity               -0.179943    8.12011e-08
#                  spoke 95% similarity              0.0681765    7.13514e-08
#                  spoke PC1                         0.0722027    1.83911e-07
#                  survey 5% similarity              -0.121184     0.00147917
#                  survey 95% similarity             0.0148081     0.00581763
#                  survey PC1                        0.0311023    0.000346284
# (dodec, indep)   confidence                                0            NaN
#                  consensus                                 0            NaN
#                  net spoke 5% similarity                   0            NaN
#                  net spoke 95% similarity                  0            NaN
#                  net spoke PC1                             0            NaN
#                  spoke 5% similarity                       0            NaN
#                  spoke 95% similarity                      0            NaN
#                  spoke PC1                                 0            NaN
#                  survey 5% similarity                      0            NaN
#                  survey 95% similarity                     0            NaN
#                  survey PC1                                0            NaN
# (dodec, inter)   confidence                         0.201013      0.0451382
#                  consensus                          -2.72917       0.311086
#                  net spoke 5% similarity          -0.0122932       0.217349
#                  net spoke 95% similarity         0.00831233      0.0149721
#                  net spoke PC1                    0.00606257      0.0163474
#                  spoke 5% similarity              -0.0912665     0.00459607
#                  spoke 95% similarity             -0.0429629       0.167968
#                  spoke PC1                         -0.023995       0.389573
#                  survey 5% similarity              -0.066697      0.0583438
#                  survey 95% similarity            -0.0309731         0.4137
#                  survey PC1                       0.00572616      0.0216648

# %% [markdown]
# # compare to the caveman baseline

# %%
eff = make_table(measurements, effect_size, network='caveman')
eff
# Out:
#                          (caveman, indep) (caveman, inter) (dodec, indep)  \
# confidence                              0          3.05513      -0.681974
# consensus                               0        -0.716453       -1.75515
# net spoke 5% similarity                 0       0.00309047      0.0323943
# net spoke 95% similarity                0       0.00342085      -0.156121
# net spoke PC1                           0       0.00455352      -0.136651
# spoke 5% similarity                     0       -0.0317362       0.113627
# spoke 95% similarity                    0       -0.0265887      -0.115736
# spoke PC1                               0       0.00419327     -0.0916162
# survey 5% similarity                    0       0.00605165      0.0887504
# survey 95% similarity                   0        0.0144075     -0.0214769
# survey PC1                              0       -0.0175696     -0.0721204
#
#                          (dodec, inter)
# confidence                      1.48635
# consensus                      -2.37906
# net spoke 5% similarity       0.0437507
# net spoke 95% similarity      -0.130024
# net spoke PC1                 -0.114209
# spoke 5% similarity           0.0558623
# spoke 95% similarity          -0.131709
# spoke PC1                    -0.0950985
# survey 5% similarity          0.0546248
# survey 95% similarity        -0.0253627
# survey PC1                   -0.0440352

# %%
eff_pval = make_table(measurements.dropna(axis=1), effect_p_val, network='caveman')
eff_pval
# Out:
#                          (caveman, indep) (caveman, inter) (dodec, indep)  \
# confidence                            NaN        0.0163334       0.645346
# consensus                             NaN         0.500056       0.173723
# net spoke 5% similarity               NaN         0.807965     0.00960872
# net spoke 95% similarity              NaN         0.866084    2.12657e-09
# net spoke PC1                         NaN         0.722699    3.46184e-11
# spoke 5% similarity                   NaN         0.261186    0.000132406
# spoke 95% similarity                  NaN        0.0288426    4.18887e-09
# spoke PC1                             NaN         0.745033    3.73473e-08
# survey 5% similarity                  NaN         0.807714    0.000126968
# survey 95% similarity                 NaN         0.408355       0.246012
# survey PC1                            NaN         0.214124     4.6386e-05
#
#                          (dodec, inter)
# confidence                     0.298291
# consensus                     0.0645604
# net spoke 5% similarity      0.00218251
# net spoke 95% similarity    2.49554e-06
# net spoke PC1               6.57352e-08
# spoke 5% similarity           0.0308809
# spoke 95% similarity        7.58097e-08
# spoke PC1                   1.21139e-06
# survey 5% similarity          0.0147092
# survey 95% similarity          0.171747
# survey PC1                   0.00753108

# %%
eff_lowerbound = make_table(measurements, effect_lowerbound, network='caveman')
eff_lowerbound
# Out:
#                          (caveman, indep) (caveman, inter) (dodec, indep)  \
# confidence                              0         0.624942       -3.61331
# consensus                               0         -2.77881       -4.17769
# net spoke 5% similarity                 0       -0.0204528      0.0115398
# net spoke 95% similarity                0       -0.0315796      -0.190152
# net spoke PC1                           0       -0.0196225      -0.162785
# spoke 5% similarity                     0       -0.0832308      0.0638545
# spoke 95% similarity                    0       -0.0486917      -0.140274
# spoke PC1                               0       -0.0161127      -0.114674
# survey 5% similarity                    0       -0.0426461       0.052509
# survey 95% similarity                   0       -0.0160445     -0.0547109
# survey PC1                              0       -0.0440793      -0.101565
#
#                          (dodec, inter)
# confidence                     -1.30872
# consensus                      -4.94378
# net spoke 5% similarity       0.0162717
# net spoke 95% similarity      -0.171642
# net spoke PC1                 -0.141936
# spoke 5% similarity          0.00852617
# spoke 95% similarity          -0.167637
# spoke PC1                     -0.123097
# survey 5% similarity          0.0141827
# survey 95% similarity        -0.0608156
# survey PC1                   -0.0736868

# %%
eff_upperbound = make_table(measurements, effect_upperbound, network='caveman')
eff_upperbound
# Out:
#                          (caveman, indep) (caveman, inter) (dodec, indep)  \
# confidence                              0          5.52012         2.0907
# consensus                               0          1.38052       0.612866
# net spoke 5% similarity                 0        0.0263142      0.0565033
# net spoke 95% similarity                0        0.0403043      -0.120166
# net spoke PC1                           0        0.0276954      -0.108491
# spoke 5% similarity                     0        0.0281616       0.161661
# spoke 95% similarity                    0      -0.00550559     -0.0895696
# spoke PC1                               0        0.0290817     -0.0659373
# survey 5% similarity                    0         0.057544       0.126509
# survey 95% similarity                   0        0.0464873      0.0123069
# survey PC1                              0       0.00811362     -0.0437191
#
#                          (dodec, inter)
# confidence                      4.19331
# consensus                     0.0048891
# net spoke 5% similarity       0.0672817
# net spoke 95% similarity     -0.0859765
# net spoke PC1                -0.0814798
# spoke 5% similarity           0.0987032
# spoke 95% similarity         -0.0926969
# spoke PC1                    -0.0666239
# survey 5% similarity           0.094245
# survey 95% similarity        0.00806497
# survey PC1                   -0.0148014

# %%
export_table = pd.DataFrame()
export_table["Result Mean"] = res.unstack()
export_table["Result Lower Bound"] = res_lowerbound.unstack()
export_table["Result Upper Bound"] = res_upperbound.unstack()
export_table["Effect Size"] = eff.unstack()
export_table["Effect Upper Bound"] = eff_upperbound.unstack()
export_table["Effect Lower Bound"] = eff_lowerbound.unstack()
export_table["Effect P Value"] = eff_pval.unstack()


export_table.to_csv(output_dir+"end_of_game_effects_summary_caveman_baseline.csv")
export_table
# Out:
#                                           Result Mean Result Lower Bound  \
# (caveman, indep) confidence                   56.0755            54.2185
#                  consensus                    57.6475            55.7411
#                  net spoke 5% similarity    -0.115098          -0.134264
#                  net spoke 95% similarity    0.252084           0.224687
#                  net spoke PC1                0.18974           0.169609
#                  spoke 5% similarity        -0.271291          -0.309194
#                  spoke 95% similarity        0.803906           0.782607
#                  spoke PC1                   0.387681            0.36952
#                  survey 5% similarity       -0.497605          -0.529969
#                  survey 95% similarity       0.689841            0.66163
#                  survey PC1                  0.380187           0.357303
# (caveman, inter) confidence                   59.1306             57.244
#                  consensus                     56.931            54.8468
#                  net spoke 5% similarity    -0.112007           -0.12864
#                  net spoke 95% similarity    0.255505           0.230246
#                  net spoke PC1               0.194293           0.175359
#                  spoke 5% similarity        -0.303028          -0.335847
#                  spoke 95% similarity        0.777318           0.757518
#                  spoke PC1                   0.391874           0.369743
#                  survey 5% similarity       -0.491553          -0.527749
#                  survey 95% similarity       0.704249           0.674998
#                  survey PC1                  0.362617           0.342451
# (dodec, indep)   confidence                   55.3935            53.0767
#                  consensus                    55.8923            53.8684
#                  net spoke 5% similarity   -0.0827036         -0.0978846
#                  net spoke 95% similarity   0.0959625          0.0759711
#                  net spoke PC1              0.0530893          0.0404301
#                  spoke 5% similarity        -0.157664          -0.193438
#                  spoke 95% similarity         0.68817           0.668767
#                  spoke PC1                   0.296064           0.278357
#                  survey 5% similarity       -0.408854          -0.438666
#                  survey 95% similarity       0.668364           0.642767
#                  survey PC1                  0.308066             0.2905
# (dodec, inter)   confidence                   57.5618            54.5643
#                  consensus                    55.2684            52.9639
#                  net spoke 5% similarity   -0.0713472         -0.0927573
#                  net spoke 95% similarity     0.12206           0.100479
#                  net spoke PC1              0.0755307          0.0596758
#                  spoke 5% similarity        -0.215429           -0.24623
#                  spoke 95% similarity        0.672197           0.644961
#                  spoke PC1                   0.292582           0.273112
#                  survey 5% similarity        -0.44298          -0.467595
#                  survey 95% similarity       0.664479           0.639452
#                  survey PC1                  0.336152           0.315717
#
#                                           Result Upper Bound Effect Size  \
# (caveman, indep) confidence                           57.944           0
#                  consensus                           59.4605           0
#                  net spoke 5% similarity          -0.0975195           0
#                  net spoke 95% similarity           0.281542           0
#                  net spoke PC1                      0.207929           0
#                  spoke 5% similarity               -0.234844           0
#                  spoke 95% similarity               0.822883           0
#                  spoke PC1                          0.406518           0
#                  survey 5% similarity              -0.466863           0
#                  survey 95% similarity              0.712307           0
#                  survey PC1                         0.402992           0
# (caveman, inter) confidence                          60.8472     3.05513
#                  consensus                           58.9566   -0.716453
#                  net spoke 5% similarity          -0.0942266  0.00309047
#                  net spoke 95% similarity           0.280059  0.00342085
#                  net spoke PC1                      0.215287  0.00455352
#                  spoke 5% similarity               -0.263206  -0.0317362
#                  spoke 95% similarity               0.797879  -0.0265887
#                  spoke PC1                          0.414314  0.00419327
#                  survey 5% similarity              -0.450175  0.00605165
#                  survey 95% similarity              0.735543   0.0144075
#                  survey PC1                         0.382222  -0.0175696
# (dodec, indep)   confidence                           57.904   -0.681974
#                  consensus                           57.9096    -1.75515
#                  net spoke 5% similarity          -0.0682537   0.0323943
#                  net spoke 95% similarity           0.113777   -0.156121
#                  net spoke PC1                     0.0670917   -0.136651
#                  spoke 5% similarity               -0.122203    0.113627
#                  spoke 95% similarity               0.708554   -0.115736
#                  spoke PC1                           0.31417  -0.0916162
#                  survey 5% similarity              -0.376392   0.0887504
#                  survey 95% similarity              0.694532  -0.0214769
#                  survey PC1                         0.326475  -0.0721204
# (dodec, inter)   confidence                          60.3482     1.48635
#                  consensus                           57.6968    -2.37906
#                  net spoke 5% similarity          -0.0521282   0.0437507
#                  net spoke 95% similarity           0.145947   -0.130024
#                  net spoke PC1                     0.0940049   -0.114209
#                  spoke 5% similarity               -0.184334   0.0558623
#                  spoke 95% similarity               0.699393   -0.131709
#                  spoke PC1                          0.311288  -0.0950985
#                  survey 5% similarity              -0.416541   0.0546248
#                  survey 95% similarity              0.690183  -0.0253627
#                  survey PC1                           0.3564  -0.0440352
#
#                                           Effect Upper Bound  \
# (caveman, indep) confidence                                0
#                  consensus                                 0
#                  net spoke 5% similarity                   0
#                  net spoke 95% similarity                  0
#                  net spoke PC1                             0
#                  spoke 5% similarity                       0
#                  spoke 95% similarity                      0
#                  spoke PC1                                 0
#                  survey 5% similarity                      0
#                  survey 95% similarity                     0
#                  survey PC1                                0
# (caveman, inter) confidence                          5.52012
#                  consensus                           1.38052
#                  net spoke 5% similarity           0.0263142
#                  net spoke 95% similarity          0.0403043
#                  net spoke PC1                     0.0276954
#                  spoke 5% similarity               0.0281616
#                  spoke 95% similarity            -0.00550559
#                  spoke PC1                         0.0290817
#                  survey 5% similarity               0.057544
#                  survey 95% similarity             0.0464873
#                  survey PC1                       0.00811362
# (dodec, indep)   confidence                           2.0907
#                  consensus                          0.612866
#                  net spoke 5% similarity           0.0565033
#                  net spoke 95% similarity          -0.120166
#                  net spoke PC1                     -0.108491
#                  spoke 5% similarity                0.161661
#                  spoke 95% similarity             -0.0895696
#                  spoke PC1                        -0.0659373
#                  survey 5% similarity               0.126509
#                  survey 95% similarity             0.0123069
#                  survey PC1                       -0.0437191
# (dodec, inter)   confidence                          4.19331
#                  consensus                         0.0048891
#                  net spoke 5% similarity           0.0672817
#                  net spoke 95% similarity         -0.0859765
#                  net spoke PC1                    -0.0814798
#                  spoke 5% similarity               0.0987032
#                  spoke 95% similarity             -0.0926969
#                  spoke PC1                        -0.0666239
#                  survey 5% similarity               0.094245
#                  survey 95% similarity            0.00806497
#                  survey PC1                       -0.0148014
#
#                                           Effect Lower Bound Effect P Value
# (caveman, indep) confidence                                0            NaN
#                  consensus                                 0            NaN
#                  net spoke 5% similarity                   0            NaN
#                  net spoke 95% similarity                  0            NaN
#                  net spoke PC1                             0            NaN
#                  spoke 5% similarity                       0            NaN
#                  spoke 95% similarity                      0            NaN
#                  spoke PC1                                 0            NaN
#                  survey 5% similarity                      0            NaN
#                  survey 95% similarity                     0            NaN
#                  survey PC1                                0            NaN
# (caveman, inter) confidence                         0.624942      0.0163334
#                  consensus                          -2.77881       0.500056
#                  net spoke 5% similarity          -0.0204528       0.807965
#                  net spoke 95% similarity         -0.0315796       0.866084
#                  net spoke PC1                    -0.0196225       0.722699
#                  spoke 5% similarity              -0.0832308       0.261186
#                  spoke 95% similarity             -0.0486917      0.0288426
#                  spoke PC1                        -0.0161127       0.745033
#                  survey 5% similarity             -0.0426461       0.807714
#                  survey 95% similarity            -0.0160445       0.408355
#                  survey PC1                       -0.0440793       0.214124
# (dodec, indep)   confidence                         -3.61331       0.645346
#                  consensus                          -4.17769       0.173723
#                  net spoke 5% similarity           0.0115398     0.00960872
#                  net spoke 95% similarity          -0.190152    2.12657e-09
#                  net spoke PC1                     -0.162785    3.46184e-11
#                  spoke 5% similarity               0.0638545    0.000132406
#                  spoke 95% similarity              -0.140274    4.18887e-09
#                  spoke PC1                         -0.114674    3.73473e-08
#                  survey 5% similarity               0.052509    0.000126968
#                  survey 95% similarity            -0.0547109       0.246012
#                  survey PC1                        -0.101565     4.6386e-05
# (dodec, inter)   confidence                         -1.30872       0.298291
#                  consensus                          -4.94378      0.0645604
#                  net spoke 5% similarity           0.0162717     0.00218251
#                  net spoke 95% similarity          -0.171642    2.49554e-06
#                  net spoke PC1                     -0.141936    6.57352e-08
#                  spoke 5% similarity              0.00852617      0.0308809
#                  spoke 95% similarity              -0.167637    7.58097e-08
#                  spoke PC1                         -0.123097    1.21139e-06
#                  survey 5% similarity              0.0141827      0.0147092
#                  survey 95% similarity            -0.0608156       0.171747
#                  survey PC1                       -0.0736868     0.00753108

# %% [markdown]
# # Interaction / Moderation

# %%
cave_effect = (measurements.xs(("caveman", "inter"), level=(0,1)) - measurements.xs(("caveman", "indep"), level=(0,1)))
dodec_effect = (measurements.xs(("dodec", "inter"), level=(0,1)) - measurements.xs(("dodec", "indep"), level=(0,1)))
df = pd.DataFrame((cave_effect - dodec_effect).mean(axis=1), columns=['Interaction'])
df['pval'] = stats.ttest_rel(cave_effect.T, dodec_effect.T)[1]
df
# Out:
#                           Interaction      pval
# confidence                   0.886805  0.622754
# consensus                   -0.092549  0.953745
# net spoke 5% similarity     -0.008266  0.631615
# net spoke 95% similarity    -0.022677  0.267805
# net spoke PC1               -0.017888  0.224151
# spoke 5% similarity          0.026029  0.504185
# spoke 95% similarity        -0.010616  0.614256
# spoke PC1                    0.007676  0.600682
# survey 5% similarity         0.040177  0.221480
# survey 95% similarity        0.018293  0.523234
# survey PC1                  -0.045655  0.033637
